# %% [markdown]
# # **Python Exploratory Data Analysis**
#
# ### **Task 1** : Indian Cars (Data Analysis)

# %% [markdown]
# # Getting an overview of the dataset

# %% [markdown]
# - Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# - Loading the dataset

# %%
ind_cars = pd.read_csv("/content/drive/MyDrive/Week 6 - Indian Cars and Superstore sales/Indian Cars/cars_ds_final.csv")

# %% [markdown]
# - Getting first 5 values of the dataset

# %%
ind_cars.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# 1                In-line  ...                      NaN                 NaN
# 2                In-line  ...                      NaN                 NaN
# 3                In-line  ...                      NaN                 NaN
# 4                In-line  ...                      NaN                 NaN
#
#   Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 0         NaN                    NaN            NaN       NaN
# 1         NaN                    NaN            NaN       NaN
# 2         NaN                    NaN            NaN       NaN
# 3         NaN                    NaN            NaN       NaN
# 4         NaN                    NaN            NaN       NaN
#
#   Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 0              NaN            NaN     NaN             NaN
# 1              NaN            NaN     NaN             NaN
# 2              NaN            NaN     NaN             NaN
# 3              NaN            NaN     NaN             NaN
# 4              NaN            NaN     NaN             NaN
#
# [5 rows x 141 columns]

# %% [markdown]
# - Getting last 5 values of the dataset

# %%
ind_cars.tail()
# Out:
#       Unnamed: 0        Make    Model        Variant Ex-Showroom_Price  \
# 1271        1271       Honda     City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda     City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda     City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda     City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi  Montero         3.2 At     Rs. 68,62,560
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 1271      1498 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1272      1498 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1273      1497 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1274      1497 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1275      3200 cc        4.0                  4.0    AWD (All Wheel Drive)
#
#      Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 1271                In-line  ...                      Yes                 NaN
# 1272                In-line  ...                      Yes                 Yes
# 1273                In-line  ...                      Yes                 Yes
# 1274                In-line  ...                      NaN                 NaN
# 1275                In-line  ...                      Yes                 NaN
#
#      Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 1271         NaN                    NaN            Yes       NaN
# 1272         NaN                    NaN            Yes       NaN
# 1273         NaN                    NaN            Yes       NaN
# 1274         NaN                    NaN            Yes       NaN
# 1275         NaN                    Yes            Yes       NaN
#
#      Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 1271              NaN            NaN     NaN             NaN
# 1272              NaN            NaN     NaN             NaN
# 1273              NaN            NaN     NaN             NaN
# 1274              NaN            NaN     NaN             NaN
# 1275              NaN            NaN     NaN             NaN
#
# [5 rows x 141 columns]

# %% [markdown]
# - Creating a copy of the original dataset

# %%
ind_cars_copy = ind_cars.copy()

# %% [markdown]
# - Making the columns of the dataset to lowercase

# %%
ind_cars_copy.columns=ind_cars_copy.columns.str.lower()

# %% [markdown]
# - Getting all the columns of the dataset

# %%
ind_cars_copy.columns
# Out:
# Index(['unnamed: 0', 'make', 'model', 'variant', 'ex-showroom_price',
#        'displacement', 'cylinders', 'valves_per_cylinder', 'drivetrain',
#        'cylinder_configuration',
#        ...
#        'leather_wrapped_steering', 'automatic_headlamps', 'engine_type',
#        'asr_/_traction_control', 'cruise_control', 'usb_ports',
#        'heads-up_display', 'welcome_lights', 'battery', 'electric_range'],
#       dtype='object', length=141)

# %% [markdown]
# - Checking for null values in the dataset

# %%
ind_cars_copy.isna().sum()
# Out:
# unnamed: 0              0
# make                   75
# model                   0
# variant                 0
# ex-showroom_price       0
#                      ...
# usb_ports            1247
# heads-up_display     1225
# welcome_lights       1207
# battery              1263
# electric_range       1259
# Length: 141, dtype: int64

# %% [markdown]
# - Getting information about the dataset

# %%
ind_cars_copy.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 141 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    unnamed: 0                                 int64
#  1    make                                       object
#  2    model                                      object
#  3    variant                                    object
#  4    ex-showroom_price                          object
#  5    displacement                               object
#  6    cylinders                                  float64
#  7    valves_per_cylinder                        float64
#  8    drivetrain                                 object
#  9    cylinder_configuration                     object
#  10   emission_norm                              object
#  11   engine_location                            object
#  12   fuel_system                                object
#  13   fuel_tank_capacity                         object
#  14   fuel_type                                  object
#  15   height                                     object
#  16   length                                     object
#  17   width                                      object
#  18   body_type                                  object
#  19   doors                                      float64
#  20   city_mileage                               object
#  21   highway_mileage                            object
#  22   arai_certified_mileage                     object
#  23   arai_certified_mileage_for_cng             object
#  24   kerb_weight                                object
#  25   gears                                      object
#  26   ground_clearance                           object
#  27   front_brakes                               object
#  28   rear_brakes                                object
#  29   front_suspension                           object
#  30   rear_suspension                            object
#  31   front_track                                object
#  32   rear_track                                 object
#  33   front_tyre_&_rim                           object
#  34   rear_tyre_&_rim                            object
#  35   power_steering                             object
#  36   power_windows                              object
#  37   power_seats                                object
#  38   keyless_entry                              object
#  39   power                                      object
#  40   torque                                     object
#  41   odometer                                   object
#  42   speedometer                                object
#  43   tachometer                                 object
#  44   tripmeter                                  object
#  45   seating_capacity                           float64
#  46   seats_material                             object
#  47   type                                       object
#  48   wheelbase                                  object
#  49   wheels_size                                object
#  50   start_/_stop_button                        object
#  51   12v_power_outlet                           object
#  52   audiosystem                                object
#  53   aux-in_compatibility                       object
#  54   average_fuel_consumption                   object
#  55   basic_warranty                             object
#  56   bluetooth                                  object
#  57   boot-lid_opener                            object
#  58   boot_space                                 object
#  59   cd_/_mp3_/_dvd_player                      object
#  60   central_locking                            object
#  61   child_safety_locks                         object
#  62   clock                                      object
#  63   cup_holders                                object
#  64   distance_to_empty                          object
#  65   door_pockets                               object
#  66   engine_malfunction_light                   object
#  67   extended_warranty                          object
#  68   fm_radio                                   object
#  69   fuel-lid_opener                            object
#  70   fuel_gauge                                 object
#  71   handbrake                                  object
#  72   instrument_console                         object
#  73   low_fuel_warning                           object
#  74   minimum_turning_radius                     object
#  75   multifunction_display                      object
#  76   sun_visor                                  object
#  77   third_row_ac_vents                         object
#  78   ventilation_system                         object
#  79   auto-dimming_rear-view_mirror              object
#  80   hill_assist                                object
#  81   gear_indicator                             object
#  82   3_point_seat-belt_in_middle_rear_seat      object
#  83   ambient_lightning                          object
#  84   cargo/boot_lights                          object
#  85   drive_modes                                object
#  86   engine_immobilizer                         object
#  87   high_speed_alert_system                    object
#  88   lane_watch_camera/_side_mirror_camera      object
#  89   passenger_side_seat-belt_reminder          object
#  90   seat_back_pockets                          object
#  91   voice_recognition                          object
#  92   walk_away_auto_car_lock                    object
#  93   abs_(anti-lock_braking_system)             object
#  94   headlight_reminder                         object
#  95   adjustable_headrests                       object
#  96   gross_vehicle_weight                       object
#  97   airbags                                    object
#  98   door_ajar_warning                          object
#  99   ebd_(electronic_brake-force_distribution)  object
#  100  fasten_seat_belt_warning                   object
#  101  gear_shift_reminder                        object
#  102  number_of_airbags                          float64
#  103  compression_ratio                          object
#  104  adjustable_steering_column                 object
#  105  other_specs                                object
#  106  other_specs                                object
#  107  parking_assistance                         object
#  108  key_off_reminder                           object
#  109  usb_compatibility                          object
#  110  android_auto                               object
#  111  apple_carplay                              object
#  112  cigarette_lighter                          object
#  113  infotainment_screen                        object
#  114  multifunction_steering_wheel               object
#  115  average_speed                              object
#  116  eba_(electronic_brake_assist)              object
#  117  seat_height_adjustment                     object
#  118  navigation_system                          object
#  119  second_row_ac_vents                        object
#  120  tyre_pressure_monitoring_system            object
#  121  rear_center_armrest                        object
#  122  ipod_compatibility                         object
#  123  esp_(electronic_stability_program)         object
#  124  cooled_glove_box                           object
#  125  recommended_tyre_pressure                  object
#  126  heated_seats                               object
#  127  turbocharger                               object
#  128  isofix_(child-seat_mount)                  object
#  129  rain_sensing_wipers                        object
#  130  paddle_shifters                            object
#  131  leather_wrapped_steering                   object
#  132  automatic_headlamps                        object
#  133  engine_type                                object
#  134  asr_/_traction_control                     object
#  135  cruise_control                             object
#  136  usb_ports                                  float64
#  137  heads-up_display                           object
#  138  welcome_lights                             object
#  139  battery                                    object
#  140  electric_range                             object
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %% [markdown]
# - Getting shape of the dataset

# %%
ind_cars_copy.shape
# Out:
# (1276, 141)

# %% [markdown]
# - Getting description of the dataset

# %%
ind_cars_copy.describe()
# Out:
#         unnamed: 0    cylinders  valves_per_cylinder        doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        seating_capacity  number_of_airbags  usb_ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# 50%            5.000000           2.000000   2.000000
# 75%            5.000000           6.000000   2.000000
# max           16.000000          14.000000   3.000000

# %% [markdown]
# - Getting a random sample from the dataset

# %%
ind_cars_copy.sample()
# Out:
#      unnamed: 0           make model         variant ex-showroom_price  \
# 364         364  Maruti Suzuki  Alto  Lxi Cng (Cng +      Rs. 4,05,570
#
#     displacement  cylinders  valves_per_cylinder               drivetrain  \
# 364       796 cc        3.0                  4.0  FWD (Front Wheel Drive)
#
#     cylinder_configuration  ... leather_wrapped_steering automatic_headlamps  \
# 364                In-line  ...                      NaN                 NaN
#
#     engine_type asr_/_traction_control cruise_control usb_ports  \
# 364         NaN                    NaN            NaN       NaN
#
#     heads-up_display welcome_lights battery  electric_range
# 364              NaN            NaN     NaN             NaN
#
# [1 rows x 141 columns]

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# - Dropping unnecessary column

# %%
ind_cars_copy = ind_cars_copy.drop('unnamed: 0', axis=1)

# %% [markdown]
# - Getting a random sample from the dataset

# %%
ind_cars_copy.sample()
# Out:
#         make            model      variant ex-showroom_price displacement  \
# 389  Hyundai  Grand I10 Prime  Era T+ Crdi      Rs. 5,68,930      1120 cc
#
#      cylinders  valves_per_cylinder               drivetrain  \
# 389        3.0                  4.0  FWD (Front Wheel Drive)
#
#     cylinder_configuration emission_norm  ... leather_wrapped_steering  \
# 389                    NaN         BS IV  ...                      NaN
#
#     automatic_headlamps engine_type asr_/_traction_control cruise_control  \
# 389                 NaN         NaN                    NaN            NaN
#
#     usb_ports heads-up_display welcome_lights  battery electric_range
# 389       NaN              NaN            NaN      NaN            NaN
#
# [1 rows x 140 columns]

# %% [markdown]
# - Dropping rows from the 'make' column which has null values

# %%
ind_cars_copy.dropna(subset=['make'], inplace=True)

# %% [markdown]
# - Performing string formatting

# %%
ind_cars_copy['ex-showroom_price'] = ind_cars_copy['ex-showroom_price'].str.replace('Rs. ', '')

ind_cars_copy['ex-showroom_price'] = ind_cars_copy['ex-showroom_price'].str.replace(',', '')

ind_cars_copy['ex-showroom_price'] = ind_cars_copy['ex-showroom_price'].astype(int)

ind_cars_copy.sample()
# Out:
# <ipython-input-106-2c33b27d7c67>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#       make model variant  ex-showroom_price displacement  cylinders  \
# 238  Isuzu  Mu-X     4X4            2931534      2999 cc        4.0
#
#      valves_per_cylinder             drivetrain cylinder_configuration  \
# 238                  4.0  AWD (All Wheel Drive)                In-line
#
#     emission_norm  ... leather_wrapped_steering automatic_headlamps  \
# 238         BS IV  ...                      Yes                 Yes
#
#     engine_type asr_/_traction_control cruise_control usb_ports  \
# 238         NaN                    Yes            Yes       NaN
#
#     heads-up_display welcome_lights  battery electric_range
# 238              NaN            NaN      NaN            NaN
#
# [1 rows x 140 columns]

# %% [markdown]
# - Dropping rows from the 'displacement' column which has null values

# %%
ind_cars_copy.dropna(subset=['displacement'], inplace=True)
# Out:
# 0

# %% [markdown]
# - Getting the count of the values present in 'drivetrain' column

# %%
ind_cars_copy['drivetrain'].value_counts()
# Out:
# FWD (Front Wheel Drive)    862
# RWD (Rear Wheel Drive)     136
# AWD (All Wheel Drive)      133
# 4WD                         53
# Name: drivetrain, dtype: int64

# %% [markdown]
# - Checking for number of null values in 'drivetrain' column

# %%
ind_cars_copy['drivetrain'].isna().sum()
# Out:
# 6

# %% [markdown]
# - Dropping rows from the 'drivetrain' column which has null values

# %%
ind_cars_copy.dropna(subset=['drivetrain'], inplace=True)
# Out:
# 0

# %% [markdown]
# - Checking for number of null values in 'cylinder_configuration' column

# %%
ind_cars_copy['cylinder_configuration'].isna().sum()
# Out:
# 8

# %% [markdown]
# - Getting the count of the values present in 'cylinder_configuration' column

# %%
ind_cars_copy['cylinder_configuration'].value_counts()
# Out:
# In-line    1029
# V           137
# W             6
# Flat          4
# Name: cylinder_configuration, dtype: int64

# %% [markdown]
# - Dropping rows from the 'cylinder_configuration' column which has null values

# %%
ind_cars_copy.dropna(subset=['cylinder_configuration'], inplace=True)
# Out:
# 0

# %% [markdown]
# - Getting the count of the values present in 'emission_norm' column

# %%
ind_cars_copy['emission_norm'].value_counts()
# Out:
# BS IV     815
# BS 6      335
# BS VI      13
# BS III      9
# Name: emission_norm, dtype: int64

# %% [markdown]
# - Checking for number of null values in 'emission_norm' column

# %%
ind_cars_copy['emission_norm'].isna().sum()
# Out:
# 4

# %% [markdown]
# - Dropping rows from the 'emission_norm' column which has null values

# %%
ind_cars_copy.dropna(subset=['emission_norm'], inplace=True)
# Out:
# 0

# %% [markdown]
# - Getting the names of the columns and putting them into a list if 'Yes' is present in them

# %%
columns_with_yes = ind_cars_copy.columns[ind_cars_copy.eq('Yes').any()]

columns_with_yes_list = columns_with_yes.tolist()

print("Columns with 'Yes':", columns_with_yes_list)
# Out:
# Columns with 'Yes': ['power_steering', 'power_seats', 'keyless_entry', 'odometer', 'speedometer', 'tachometer', 'tripmeter', 'start_/_stop_button', '12v_power_outlet', 'aux-in_compatibility', 'average_fuel_consumption', 'bluetooth', 'cd_/_mp3_/_dvd_player', 'central_locking', 'child_safety_locks', 'clock', 'cup_holders', 'distance_to_empty', 'door_pockets', 'engine_malfunction_light', 'fm_radio', 'fuel_gauge', 'low_fuel_warning', 'multifunction_display', 'third_row_ac_vents', 'ventilation_system', 'auto-dimming_rear-view_mirror', 'hill_assist', 'gear_indicator', '3_point_seat-belt_in_middle_rear_seat', 'ambient_lightning', 'cargo/boot_lights', 'engine_immobilizer', 'high_speed_alert_system', 'lane_watch_camera/_side_mirror_camera', 'passenger_side_seat-belt_reminder', 'seat_back_pockets', 'voice_recognition', 'walk_away_auto_car_lock', 'abs_(anti-lock_braking_system)', 'headlight_reminder', 'adjustable_headrests', 'airbags', 'door_ajar_warning', 'ebd_(electronic_brake-force_distribution)', 'fasten_seat_belt_warning', 'gear_shift_reminder', 'adjustable_steering_column', 'parking_assistance', 'key_off_reminder', 'usb_compatibility', 'android_auto', 'apple_carplay', 'cigarette_lighter', 'infotainment_screen', 'multifunction_steering_wheel', 'average_speed', 'eba_(electronic_brake_assist)', 'navigation_system', 'second_row_ac_vents', 'tyre_pressure_monitoring_system', 'rear_center_armrest', 'ipod_compatibility', 'esp_(electronic_stability_program)', 'cooled_glove_box', 'heated_seats', 'turbocharger', 'isofix_(child-seat_mount)', 'rain_sensing_wipers', 'paddle_shifters', 'leather_wrapped_steering', 'automatic_headlamps', 'asr_/_traction_control', 'cruise_control', 'heads-up_display', 'welcome_lights']

# %% [markdown]
# - Filing the null values to the columns_with_yes with 'No' in place of null (NaN) value

# %%
ind_cars_copy[columns_with_yes_list] = ind_cars_copy[columns_with_yes_list].fillna('No')

# %% [markdown]
# - Getting the names of the columns which is null and of object datatype (Exluding the numeric columns)

# %%
object_columns_with_nan = ind_cars_copy.columns[(ind_cars_copy.isnull().any()) & (ind_cars_copy.dtypes == 'object')]

object_columns_with_nan_list = object_columns_with_nan.tolist()

print("Object columns with NaN values:", object_columns_with_nan_list)
# Out:
# Object columns with NaN values: ['engine_location', 'fuel_tank_capacity', 'height', 'width', 'body_type', 'city_mileage', 'highway_mileage', 'arai_certified_mileage', 'arai_certified_mileage_for_cng', 'kerb_weight', 'gears', 'ground_clearance', 'front_brakes', 'rear_brakes', 'front_suspension', 'rear_suspension', 'front_track', 'rear_track', 'front_tyre_&_rim', 'rear_tyre_&_rim', 'power_windows', 'torque', 'seats_material', 'wheelbase', 'wheels_size', 'audiosystem', 'basic_warranty', 'boot-lid_opener', 'boot_space', 'extended_warranty', 'fuel-lid_opener', 'handbrake', 'instrument_console', 'minimum_turning_radius', 'sun_visor', 'drive_modes', 'gross_vehicle_weight', 'compression_ratio', 'other_specs', 'other_specs', 'seat_height_adjustment', 'recommended_tyre_pressure', 'engine_type', 'battery', 'electric_range']

# %% [markdown]
# - Filing the null values to the object_columns_with_nan with 'Not Available' in place of null (NaN) value

# %%
replace_values = {column: 'Not Available' for column in object_columns_with_nan}

ind_cars_copy.fillna(replace_values, inplace=True)

# %% [markdown]
# - Getting information about the dataset

# %%
ind_cars_copy.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1172 entries, 0 to 1275
# Data columns (total 140 columns):
#  #    Column                                     Dtype
# ---   ------                                     -----
#  0    make                                       object
#  1    model                                      object
#  2    variant                                    object
#  3    ex-showroom_price                          int64
#  4    displacement                               object
#  5    cylinders                                  float64
#  6    valves_per_cylinder                        float64
#  7    drivetrain                                 object
#  8    cylinder_configuration                     object
#  9    emission_norm                              object
#  10   engine_location                            object
#  11   fuel_system                                object
#  12   fuel_tank_capacity                         object
#  13   fuel_type                                  object
#  14   height                                     object
#  15   length                                     object
#  16   width                                      object
#  17   body_type                                  object
#  18   doors                                      float64
#  19   city_mileage                               object
#  20   highway_mileage                            object
#  21   arai_certified_mileage                     object
#  22   arai_certified_mileage_for_cng             object
#  23   kerb_weight                                object
#  24   gears                                      object
#  25   ground_clearance                           object
#  26   front_brakes                               object
#  27   rear_brakes                                object
#  28   front_suspension                           object
#  29   rear_suspension                            object
#  30   front_track                                object
#  31   rear_track                                 object
#  32   front_tyre_&_rim                           object
#  33   rear_tyre_&_rim                            object
#  34   power_steering                             object
#  35   power_windows                              object
#  36   power_seats                                object
#  37   keyless_entry                              object
#  38   power                                      object
#  39   torque                                     object
#  40   odometer                                   object
#  41   speedometer                                object
#  42   tachometer                                 object
#  43   tripmeter                                  object
#  44   seating_capacity                           float64
#  45   seats_material                             object
#  46   type                                       object
#  47   wheelbase                                  object
#  48   wheels_size                                object
#  49   start_/_stop_button                        object
#  50   12v_power_outlet                           object
#  51   audiosystem                                object
#  52   aux-in_compatibility                       object
#  53   average_fuel_consumption                   object
#  54   basic_warranty                             object
#  55   bluetooth                                  object
#  56   boot-lid_opener                            object
#  57   boot_space                                 object
#  58   cd_/_mp3_/_dvd_player                      object
#  59   central_locking                            object
#  60   child_safety_locks                         object
#  61   clock                                      object
#  62   cup_holders                                object
#  63   distance_to_empty                          object
#  64   door_pockets                               object
#  65   engine_malfunction_light                   object
#  66   extended_warranty                          object
#  67   fm_radio                                   object
#  68   fuel-lid_opener                            object
#  69   fuel_gauge                                 object
#  70   handbrake                                  object
#  71   instrument_console                         object
#  72   low_fuel_warning                           object
#  73   minimum_turning_radius                     object
#  74   multifunction_display                      object
#  75   sun_visor                                  object
#  76   third_row_ac_vents                         object
#  77   ventilation_system                         object
#  78   auto-dimming_rear-view_mirror              object
#  79   hill_assist                                object
#  80   gear_indicator                             object
#  81   3_point_seat-belt_in_middle_rear_seat      object
#  82   ambient_lightning                          object
#  83   cargo/boot_lights                          object
#  84   drive_modes                                object
#  85   engine_immobilizer                         object
#  86   high_speed_alert_system                    object
#  87   lane_watch_camera/_side_mirror_camera      object
#  88   passenger_side_seat-belt_reminder          object
#  89   seat_back_pockets                          object
#  90   voice_recognition                          object
#  91   walk_away_auto_car_lock                    object
#  92   abs_(anti-lock_braking_system)             object
#  93   headlight_reminder                         object
#  94   adjustable_headrests                       object
#  95   gross_vehicle_weight                       object
#  96   airbags                                    object
#  97   door_ajar_warning                          object
#  98   ebd_(electronic_brake-force_distribution)  object
#  99   fasten_seat_belt_warning                   object
#  100  gear_shift_reminder                        object
#  101  number_of_airbags                          float64
#  102  compression_ratio                          object
#  103  adjustable_steering_column                 object
#  104  other_specs                                object
#  105  other_specs                                object
#  106  parking_assistance                         object
#  107  key_off_reminder                           object
#  108  usb_compatibility                          object
#  109  android_auto                               object
#  110  apple_carplay                              object
#  111  cigarette_lighter                          object
#  112  infotainment_screen                        object
#  113  multifunction_steering_wheel               object
#  114  average_speed                              object
#  115  eba_(electronic_brake_assist)              object
#  116  seat_height_adjustment                     object
#  117  navigation_system                          object
#  118  second_row_ac_vents                        object
#  119  tyre_pressure_monitoring_system            object
#  120  rear_center_armrest                        object
#  121  ipod_compatibility                         object
#  122  esp_(electronic_stability_program)         object
#  123  cooled_glove_box                           object
#  124  recommended_tyre_pressure                  object
#  125  heated_seats                               object
#  126  turbocharger                               object
#  127  isofix_(child-seat_mount)                  object
#  128  rain_sensing_wipers                        object
#  129  paddle_shifters                            object
#  130  leather_wrapped_steering                   object
#  131  automatic_headlamps                        object
#  132  engine_type                                object
#  133  asr_/_traction_control                     object
#  134  cruise_control                             object
#  135  usb_ports                                  float64
#  136  heads-up_display                           object
#  137  welcome_lights                             object
#  138  battery                                    object
#  139  electric_range                             object
# dtypes: float64(6), int64(1), object(133)
# memory usage: 1.3+ MB

# %% [markdown]
# - Checking for null valuess in the dataset

# %%
ind_cars_copy.isna().sum()
# Out:
# make                    0
# model                   0
# variant                 0
# ex-showroom_price       0
# displacement            0
#                      ...
# usb_ports            1143
# heads-up_display        0
# welcome_lights          0
# battery                 0
# electric_range          0
# Length: 140, dtype: int64

# %% [markdown]
# - Filling the null values of 'usb_ports' columns with 0

# %%
ind_cars_copy['usb_ports'].fillna(0, inplace=True)

# %% [markdown]
# - Getting description about the dataset

# %%
ind_cars_copy.describe()
# Out:
#        ex-showroom_price    cylinders  valves_per_cylinder        doors  \
# count       1.172000e+03  1124.000000          1091.000000  1168.000000
# mean        3.831528e+06     4.264235             3.974335     4.577911
# std         1.098235e+07     1.465702             0.862725     0.722339
# min         2.364470e+05     2.000000             1.000000     2.000000
# 25%         7.315598e+05     4.000000             4.000000     4.000000
# 50%         9.999000e+05     4.000000             4.000000     5.000000
# 75%         2.115975e+06     4.000000             4.000000     5.000000
# max         2.121554e+08    16.000000            16.000000     5.000000
#
#        seating_capacity  number_of_airbags    usb_ports
# count       1167.000000        1051.000000  1172.000000
# mean           5.286204           3.588011     0.044369
# std            1.149393           2.436353     0.303260
# min            2.000000           1.000000     0.000000
# 25%            5.000000           2.000000     0.000000
# 50%            5.000000           2.000000     0.000000
# 75%            5.000000           6.000000     0.000000
# max           16.000000          14.000000     3.000000

# %% [markdown]
# - Getting 5 random samples from the dataset

# %%
ind_cars_copy.sample(5)
# Out:
#                make       model         variant  ex-showroom_price  \
# 398        Mahindra  Kuv100 Nxt      K4+ D 6Str             667273
# 376   Maruti Suzuki    S-Presso        Vxi+ Ags             499000
# 1201         Nissan       Kicks  Xv Premium (O)            1465000
# 336         Porsche    Panamera           Turbo           21263000
# 959   Maruti Suzuki     S-Cross      1.3L Alpha            1143689
#
#      displacement  cylinders  valves_per_cylinder               drivetrain  \
# 398       1198 cc        3.0                  4.0  FWD (Front Wheel Drive)
# 376        998 cc        3.0                  4.0  FWD (Front Wheel Drive)
# 1201      1461 cc        4.0                  NaN   RWD (Rear Wheel Drive)
# 336       3996 cc        8.0                  4.0    AWD (All Wheel Drive)
# 959       1248 cc        4.0                  4.0  FWD (Front Wheel Drive)
#
#      cylinder_configuration emission_norm  ... leather_wrapped_steering  \
# 398                 In-line         BS IV  ...                       No
# 376                 In-line          BS 6  ...                       No
# 1201                In-line          BS 6  ...                       No
# 336                       V         BS IV  ...                      Yes
# 959                 In-line         BS IV  ...                      Yes
#
#      automatic_headlamps    engine_type asr_/_traction_control cruise_control  \
# 398                   No  Not Available                     No             No
# 376                   No  Not Available                     No             No
# 1201                  No  Not Available                    Yes             No
# 336                  Yes  Not Available                    Yes            Yes
# 959                  Yes  Not Available                     No            Yes
#
#      usb_ports heads-up_display welcome_lights        battery electric_range
# 398        0.0               No             No  Not Available  Not Available
# 376        0.0               No             No  Not Available  Not Available
# 1201       0.0               No             No  Not Available  Not Available
# 336        0.0               No             No  Not Available  Not Available
# 959        0.0               No             No  Not Available  Not Available
#
# [5 rows x 140 columns]

# %% [markdown]
# #**Data Visualization**

# %% [markdown]
# - Visualizing distribution of Ex-Showroom price

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(y=ind_cars_copy['ex-showroom_price'], bins=30, kde=False)
plt.title('Distribution of Ex-Showroom Price')
plt.xlabel('Frequency')
plt.ylabel('Ex-Showroom Price')

ax.get_yaxis().get_major_formatter().set_scientific(False)

plt.show()

# %% [markdown]
# - Visualizing the count of Car Manufacturers

# %%
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='make', data=ind_cars_copy)
plt.title('Count of Car Manufacturers')
plt.xlabel('Car Manufacturers')
plt.ylabel('Count')
plt.xticks(rotation=90)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=9, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()

# %% [markdown]
# - Visualizing the Manufacturers and their respective Models via sunburst chart

# %%
fig = px.sunburst(ind_cars_copy, path=['make', 'model'], title='Manufacturers and Models Sunburst Chart', hover_name = 'model')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="26f30b24-61be-4f03-8f1e-7edb7f6e2fad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26f30b24-61be-4f03-8f1e-7edb7f6e2fad")) {                    Plotly.newPlot(                        "26f30b24-61be-4f03-8f1e-7edb7f6e2fad",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elabels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["3-Series","458 Speciale","458 Spider","488 Gtb","5-Series","6-Series","7-Series","718","812 Superfast","911","A3","A3 Cabriolet","A4","A5","A5 Cabriolet","A6","A8 L","Abarth Avventura","Abarth Punto","Accord Hybrid","Alto","Alto 800 Tour","Alto K10","Altroz","Alturas G4","Amaze","Ameo","Aspire","Aura","Avanti","Aventador","Avventura","Baleno","Baleno Rs","Bentayga","Bolero","Bolero Power Plus","Bolt","Brv","Camry","Captur","Carnival","Cayenne","Cayenne Coupe","Celerio","Celerio Tour","Celerio X","Chiron","Ciaz","City","Civic","Compass","Compass Trailhawk","Continental Gt","Convertible","Cooper 3 Door","Cooper 5 Door","Corolla Altis","Countryman","Cr-V","Creta","Discovery","Discovery Sport","Dmax V-Cross","Duster","Dzire","Dzire Tour","Ecosport","Eeco","Elantra","Elite I20","Endeavour","Ertiga","Es","Etios Cross","Etios Liva","Extreme","F-Pace","F-Type","Figo","Flying Spur","Fortuner","Freestyle","Glanza","Go","Grancabrio","Grand Cherokee","Grand I10","Grand I10 Nios","Grand I10 Prime","Granturismo","Gtc4 Lusso","Gtr","Gurkha","Gypsy","Harrier","Hector","Hexa","Huracan","I20 Active","Ignis","Innova Crysta","Jazz","John Cooper Works","Kicks","Kodiaq","Kodiaq Scout","Kuv100 Nxt","Kwid","Land Cruiser","Land Cruiser Prado","Lc 500H","Levante","Linea","Linea Classic","Lodgy","Ls 500H","Lx 450D","Lx 570","M2 Competition","M4","M5","Macan","Marazzo","Micra","Micra Active","Monte Carlo","Montero","Mu-X","Mulsanne","Mustang","Nano Genx","Nexon","Nuvosport","Nx 300H","Octavia","Omni","Pajero Sport","Panamera","Passat","Platinum Etios","Polo","Portofino","Prius","Punto Evo","Punto Evo Pure","Q3","Q5","Q7","Q8","Quattroporte","Qute (Re60)","R8","Range","Range Evoque","Range Evoque Convertible","Range Sport","Range Velar","Rapid","Rapide","Redi-Go","Rio","Rs5","Rs7","Rx 450H","S-Cross","S-Presso","S5","S60","S60 Cross Country","S90","Safari Storme","Santro","Scorpio","Seltos","Sunny","Superb","Superb Sportline","Swift","Terrano","Thar","Tiago","Tiago Nrg","Tigor","Tiguan","Triber","Tucson","Tuv300","Tuv300 Plus","Urban Cross","Urus","V40","V40 Cross Country","V90 Cross Country","Vantage","Vento","Venue","Verito","Verito Vibe","Verna","Vitara Brezza","Wagon","Winger","Wr-V","Wrangler","X1","X3","X4","X5","X7","Xc40","Xc60","Xc90","Xcent","Xcent Prime","Xe","Xf","Xj","Xl6","Xuv300","Xuv500","Xylo","Yaris","Z4 Roadster","Zest","(?)","(?)","Qute (Re60)","(?)","(?)","Chiron","(?)","Avanti","(?)","(?)","Gurkha","(?)","(?)","(?)","Extreme","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","Wagon","(?)","Hector","(?)","(?)","(?)","(?)","Rio","(?)","(?)","(?)","(?)","(?)","(?)"],"ids":["Bmw\u002f3-Series","Ferrari\u002f458 Speciale","Ferrari\u002f458 Spider","Ferrari\u002f488 Gtb","Bmw\u002f5-Series","Bmw\u002f6-Series","Bmw\u002f7-Series","Porsche\u002f718","Ferrari\u002f812 Superfast","Porsche\u002f911","Audi\u002fA3","Audi\u002fA3 Cabriolet","Audi\u002fA4","Audi\u002fA5","Audi\u002fA5 Cabriolet","Audi\u002fA6","Audi\u002fA8 L","Fiat\u002fAbarth Avventura","Fiat\u002fAbarth Punto","Honda\u002fAccord Hybrid","Maruti Suzuki\u002fAlto","Maruti Suzuki\u002fAlto 800 Tour","Maruti Suzuki\u002f ...

# %% [markdown]
# - Visualizing Box Plot of all numeric columns

# %%
numeric_columns = ind_cars_copy.select_dtypes(include='number').columns

plt.figure(figsize=(16, 8))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(1, len(numeric_columns), i)
    sns.boxplot(x=ind_cars_copy[column])
    plt.title(f'Box Plot of {column}', fontsize = 7.5, fontweight = 'bold')

plt.show()

# %% [markdown]
# - Visualizing Correlation Matrix

# %%
numeric_columns = ind_cars_copy.select_dtypes(include='number')

correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numeric Variables')
plt.show()

# %% [markdown]
# - Visualizing the scatter plot of Seating Capacity vs Number of Airbags with Ex-Showroom Price

# %%
plt.figure(figsize=(12, 8))
plt.scatter(ind_cars_copy['seating_capacity'], ind_cars_copy['number_of_airbags'], c=ind_cars_copy['ex-showroom_price'], cmap='viridis', alpha=0.7)
plt.colorbar(label='Ex-Showroom Price')
plt.xlabel('Seating Capacity')
plt.ylabel('Number of Airbags')
plt.title('Scatter Plot: Seating Capacity vs Number of Airbags with Ex-Showroom Price')
plt.show()

# %% [markdown]
# - Visualizing pair-plot for numeric data

# %%
numeric_columns = ind_cars_copy.select_dtypes(include='number')

sns.pairplot(numeric_columns)
plt.suptitle('Pair Plot of Numeric Variables', y=1.02)
plt.show()

# %% [markdown]
# - Visualizing the count of Car Models with Manufacturers

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='model', hue='make', data=ind_cars_copy)
plt.title('Count of Car Models with Manufacturers')
plt.xlabel('Car Models')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Manufacturers', loc='upper right')
plt.show()

# %% [markdown]
# - Visualzing the joint Plot of Seating Capacity vs Ex-Showroom Price

# %%
sns.jointplot(x='seating_capacity', y='ex-showroom_price', data=ind_cars_copy, kind='scatter')
plt.suptitle('Joint Plot: Seating Capacity vs Ex-Showroom Price', y=1.02)
plt.show()

# %% [markdown]
# - Visualizing the box Plot of Ex-Showroom Price by Manufacturers with Car Models

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='make', y='ex-showroom_price', hue='model', data=ind_cars_copy)
plt.title('Box Plot: Ex-Showroom Price by Manufacturers with Car Models')
plt.xlabel('Manufacturers')
plt.ylabel('Ex-Showroom Price')
plt.xticks(rotation=90)
plt.legend(title='Car Models', loc='best')
plt.show()

# %% [markdown]
# - Visualizing the categorical Plot of Ex-Showroom Price by Car Model

# %%
plt.figure(figsize=(12, 8))
sns.catplot(x='ex-showroom_price', y='make', data=ind_cars_copy, kind='box')
plt.title('Categorical Plot: Ex-Showroom Price by Car Model')
plt.ylabel('Car Models')
plt.xlabel('Ex-Showroom Price')
plt.show()

# %% [markdown]
# - Visualizing the violin plot for numeric columns

# %%
numeric_columns = ind_cars_copy.select_dtypes(include='number')

plt.figure(figsize=(16, 8))
for i, column in enumerate(numeric_columns.columns, 1):
    plt.subplot(1, len(numeric_columns.columns), i)
    sns.violinplot(x=column, data=ind_cars_copy)
    plt.title(f'Violin Plot: {column}')
    plt.xlabel(column)

plt.tight_layout()
plt.show()
